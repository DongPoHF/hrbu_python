# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import time

# %%
#功能：获取本地时间戳
time.time()
# Out:
# 1662431829.8675408

# %%
# strftime()
#格式化时间字符串
#time.strfitime('时间字符串的格式',[时间元组])
#返回值：格式化完成的时间字符串
time.strftime('%Y-%m-%d %H:%M:%S %a')
time.strftime('%Y-%m-%d %j %U %w %H')
# Out:
# '2022-09-06 249 36 2 11'

# %%
#strptime
#解析时间字符串成一个元组,strftime的逆向操作
