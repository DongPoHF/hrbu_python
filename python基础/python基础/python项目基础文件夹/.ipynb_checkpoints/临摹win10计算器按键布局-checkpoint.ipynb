# %%
import tkinter

# %%
root= tkinter.Tk()
root.minsize(457,754)
root.maxsize(457,754)

###按键
btnp=tkinter.Button(root,text='+/-',font=('微软雅黑',13),bg='White')
btn0=tkinter.Button(root,text='0',font=('微软雅黑',13,'bold'),bg='White')
btnpo=tkinter.Button(root,text='.',font=('微软雅黑',13),bg='White')
btn1=tkinter.Button(root,text='1',font=('微软雅黑',13,'bold'),bg='White')
btn2=tkinter.Button(root,text='2',font=('微软雅黑',13,'bold'),bg='White')
btn3=tkinter.Button(root,text='3',font=('微软雅黑',13,'bold'),bg='White')
btn4=tkinter.Button(root,text='4',font=('微软雅黑',13,'bold'),bg='White')
btn5=tkinter.Button(root,text='5',font=('微软雅黑',13,'bold'),bg='White')
btn6=tkinter.Button(root,text='6',font=('微软雅黑',13,'bold'),bg='White')
btn7=tkinter.Button(root,text='7',font=('微软雅黑',13,'bold'),bg='White')
btn8=tkinter.Button(root,text='8',font=('微软雅黑',13,'bold'),bg='White')
btn9=tkinter.Button(root,text='9',font=('微软雅黑',13,'bold'),bg='White')
btneq=tkinter.Button(root,text='=',font=('微软雅黑',18),bg='LightBlue',fg='black')
btnpl=tkinter.Button(root,text='＋',font=('微软雅黑',18))
btnsub=tkinter.Button(root,text='－',font=('微软雅黑',18))
btnmul=tkinter.Button(root,text='×',font=('宋体',18))
btndiv=tkinter.Button(root,text='÷',font=('宋体',18))
btnbc=tkinter.Button(root,text='退格',font=('宋体',13))
btnqu=tkinter.Button(root,text='¹/x',font=('宋体',13))
btnsqu=tkinter.Button(root,text='x²',font=('宋体',13))
btnsqrt=tkinter.Button(root,text='√x',font=('宋体',13))
btnbf=tkinter.Button(root,text='%',font=('宋体',13))
btnce=tkinter.Button(root,text='CE',font=('宋体',13))
btnc=tkinter.Button(root,text='C',font=('宋体',13))
btnmc=tkinter.Button(root,text='MC',font=('微软雅黑',10),bd=0)
btnmr=tkinter.Button(root,text='MR',font=('微软雅黑',10,),bd=0)
btnmp=tkinter.Button(root,text='M+',font=('微软雅黑',10,),bd=0)
btnmsu=tkinter.Button(root,text='M-',font=('微软雅黑',10,),bd=0)
btnms=tkinter.Button(root,text='MS',font=('微软雅黑',10,),bd=0)
btnm=tkinter.Button(root,text='M',font=('微软雅黑',10,),bd=0)

label_1=tkinter.Label(root,text='0',font=('微软雅黑',30,'bold'),anchor='e')

### 布局(绝对布局)
btnp.place(x=4,y=669,height=80,width=110)
btn0.place(x=117,y=669,height=80,width=110)
btnpo.place(x=230,y=669,height=80,width=110)
btn1.place(x=4,y=585,height=80,width=110)
btn2.place(x=117,y=585,height=80,width=110)
btn3.place(x=230,y=585,height=80,width=110)
btn4.place(x=4,y=501,height=80,width=110)
btn5.place(x=117,y=501,height=80,width=110)
btn6.place(x=230,y=501,height=80,width=110)
btn7.place(x=4,y=416,height=80,width=110)
btn8.place(x=117,y=416,height=80,width=110)
btn9.place(x=230,y=416,height=80,width=110)
btneq.place(x=343,y=669,height=80,width=110)
btnpl.place(x=343,y=585,height=80,width=110) #加
btnsub.place(x=343,y=501,height=80,width=110) #减
btnmul.place(x=343,y=416,height=80,width=110)
btndiv.place(x=343,y=332,height=80,width=110)
btnbc.place(x=343,y=247,height=80,width=110) #退格
btnqu.place(x=4,y=332,height=80,width=110)   #1/x
btnsqu.place(x=117,y=332,height=80,width=110) #平方
btnsqrt.place(x=230,y=332,height=80,width=110)   
btnbf.place(x=4,y=247,height=80,width=110) #%
btnce.place(x=117,y=247,height=80,width=110)
btnc.place(x=230,y=247,height=80,width=110)

btnmc.place(x=4,y=194,height=50,width=72)
btnmr.place(x=79,y=194,height=50,width=72)
btnmp.place(x=154,y=194,height=50,width=72)
btnmsu.place(x=229,y=194,height=50,width=72)
btnms.place(x=304,y=194,height=50,width=72)
btnm.place(x=379,y=194,height=50,width=72)

label_1.place(x=0,y=67,width=457,height=100)


root.mainloop()

# %%
root= tkinter.Tk()
root.minsize(457,754)

###按键
btnp=tkinter.Button(root,text='+/-',font=('微软雅黑',13),bg='White')
btn0=tkinter.Button(root,text='0',font=('微软雅黑',13,'bold'),bg='White')
btnpo=tkinter.Button(root,text='.',font=('微软雅黑',13),bg='White')
btn1=tkinter.Button(root,text='1',font=('微软雅黑',13,'bold'),bg='White')
btn2=tkinter.Button(root,text='2',font=('微软雅黑',13,'bold'),bg='White')
btn3=tkinter.Button(root,text='3',font=('微软雅黑',13,'bold'),bg='White')
btn4=tkinter.Button(root,text='4',font=('微软雅黑',13,'bold'),bg='White')
btn5=tkinter.Button(root,text='5',font=('微软雅黑',13,'bold'),bg='White')
btn6=tkinter.Button(root,text='6',font=('微软雅黑',13,'bold'),bg='White')
btn7=tkinter.Button(root,text='7',font=('微软雅黑',13,'bold'),bg='White')
btn8=tkinter.Button(root,text='8',font=('微软雅黑',13,'bold'),bg='White')
btn9=tkinter.Button(root,text='9',font=('微软雅黑',13,'bold'),bg='White')
btneq=tkinter.Button(root,text='=',font=('微软雅黑',18),bg='LightBlue',fg='black')
btnpl=tkinter.Button(root,text='＋',font=('微软雅黑',18))
btnsub=tkinter.Button(root,text='－',font=('微软雅黑',18))
btnmul=tkinter.Button(root,text='×',font=('宋体',18))
btndiv=tkinter.Button(root,text='÷',font=('宋体',18))
btnbc=tkinter.Button(root,text='退格',font=('宋体',13))
btnqu=tkinter.Button(root,text='¹/x',font=('宋体',13))
btnsqu=tkinter.Button(root,text='x²',font=('宋体',13))
btnsqrt=tkinter.Button(root,text='√x',font=('宋体',13))
btnbf=tkinter.Button(root,text='%',font=('宋体',13))
btnce=tkinter.Button(root,text='CE',font=('宋体',13))
btnc=tkinter.Button(root,text='C',font=('宋体',13))
btnmc=tkinter.Button(root,text='MC',font=('微软雅黑',10),bd=0)
btnmr=tkinter.Button(root,text='MR',font=('微软雅黑',10,),bd=0)
btnmp=tkinter.Button(root,text='M+',font=('微软雅黑',10,),bd=0)
btnmsu=tkinter.Button(root,text='M-',font=('微软雅黑',10,),bd=0)
btnms=tkinter.Button(root,text='MS',font=('微软雅黑',10,),bd=0)
btnm=tkinter.Button(root,text='M',font=('微软雅黑',10,),bd=0)

label_1=tkinter.Label(root,text='0',font=('微软雅黑',30,'bold'),anchor='e')

#布局  (相对布局)
btnp.place(relx=0.008,rely=0.887,relheight=0.106,relwidth=0.240)
btn0.place(relx=0.256,rely=0.887,relheight=0.106,relwidth=0.240)
btnpo.place(relx=0.503,rely=0.887,relheight=0.106,relwidth=0.240)
btneq.place(relx=0.750,rely=0.887,relheight=0.106,relwidth=0.240)
btn1.place(relx=0.008,rely=0.775,relheight=0.106,relwidth=0.240)
btn2.place(relx=0.256,rely=0.775,relheight=0.106,relwidth=0.240)
btn3.place(relx=0.503,rely=0.775,relheight=0.106,relwidth=0.240)
btn4.place(relx=0.008,rely=0.664,relheight=0.106,relwidth=0.240)
btn5.place(relx=0.256,rely=0.664,relheight=0.106,relwidth=0.240)
btn6.place(relx=0.503,rely=0.664,relheight=0.106,relwidth=0.240)
btn7.place(relx=0.008,rely=0.551,relheight=0.106,relwidth=0.240)
btn8.place(relx=0.256,rely=0.551,relheight=0.106,relwidth=0.240)
btn9.place(relx=0.503,rely=0.551,relheight=0.106,relwidth=0.240)

btneq.place(relx=0.750,rely=0.887,relheight=0.106,relwidth=0.240)
btnpl.place(relx=0.750,rely=0.775,relheight=0.106,relwidth=0.240)
btnsub.place(relx=0.750,rely=0.664,relheight=0.106,relwidth=0.240)
btnmul.place(relx=0.750,rely=0.551,relheight=0.106,relwidth=0.240)
btndiv.place(relx=0.750,rely=0.440,relheight=0.106,relwidth=0.240)
btnbc.place(relx=0.750,rely=0.327,relheight=0.106,relwidth=0.240)
btnqu.place(relx=0.008,rely=0.440,relheight=0.106,relwidth=0.240)
btnsqu.place(relx=0.256,rely=0.440,relheight=0.106,relwidth=0.240)
btnsqrt.place(relx=0.503,rely=0.440,relheight=0.106,relwidth=0.240)
btnbf.place(relx=0.008,rely=0.327,relheight=0.106,relwidth=0.240)
btnce.place(relx=0.256,rely=0.327,relheight=0.106,relwidth=0.240)
btnc.place(relx=0.503,rely=0.327,relheight=0.106,relwidth=0.240)


btnmc.place(relx=0.008,rely=0.257,relheight=0.066,relwidth=0.157)
btnmr.place(relx=0.172,rely=0.257,relheight=0.066,relwidth=0.157)
btnmp.place(relx=0.336,rely=0.257,relheight=0.066,relwidth=0.157)
btnmsu.place(relx=0.501,rely=0.257,relheight=0.066,relwidth=0.157)
btnms.place(relx=0.665,rely=0.257,relheight=0.066,relwidth=0.157)
btnm.place(relx=0.829,rely=0.257,relheight=0.066,relwidth=0.157)

label_1.place(relx=0,rely=0.088,relwidth=1,relheight=0.132)

root.mainloop()
